# %% [markdown]
# # **random variables**

# %% [markdown]
# **variable >>** a variable in a computer program is used stope various types of data.
# > so, **random variable** is a set of possible values from a random experiment.
#
# example >> `tossing a coin` this experiment is random -> the outcome could be head ot tail.
# we need to quantify these random values of the experiment -> in this case **head** and **tail**
# let's say **x** represent the experiment, H is head, and T is tail. then >>
# ![experiment x](./img_data/experiment_x.png)
# here we can assume
# 0 -> tail, and
# 1 -> heads
# *we're mapping 0 to tail and 1 to head. but we could've done the opposite. doesn't really matter.*
# ```text
# here x is a random variable, mainly 'cause it can be of any value from the set of possible values.
# in this case 0 and 1.
# ```

# %% [markdown]
# > in **algebra** the resultant value is generally deterministic.
#
# example i >>
#    **x - 5 = 10**
# =>     x = 10 - 5
# =>     x = 5 ------> deterministic value (this is fixed)
#
# example ii >>
# **x = {1, 2, 3, 4, 5, 6}** ------> sample space
# - say someone throughs a dice. what is the probablity that we'll be getting a 1 and will be getting a 6?
#
# `probablity (P) = number of possible outcomes / total number of outcomes`
#
# - P(x=1) = 1/6, and
# - P(x=6) = 1/6

# %% [markdown]
# example iii >>
# say you're tossing a coin
# probablity od getting a head (H),
# **P(x=H) = 1/2**
