# %% [markdown]
# # **introduction to statistics**
# <p>notebook by: jatin kumar mehta | @jkmloom</p>

# %% [markdown]
# **defination >>** statistics is a mathematical science (including methods for collecting, organizing, and analyzing data in such a way that meaningful conclusion/s can be drawn)
#
# * is covered in detail later
# **statistics type** (based on applicaiton) >> 1. descriptive, and 2. inferential

# %% [markdown]
# ### **why statistics is used in data science?**
# - to learn from the pattern/s in data (very general defination)
# **data >>** facts or pieces of information that can be stored, measured and re-accessed
# - data is used to bring insights (for making decisions)

# %% [markdown]
# **example >>**
# ranking players based on their gameplay (game: valorant)
# let's assume the players to be: **jkmloom, jkmloomdev, hetmind**
# ranking could be anything (based on the data): say >> 1st. hetmind, 2nd. jkmloomdev, and 3rd. jkmloom

# %% [markdown]
# **few more examples >>**
# 1. product improvement >> analyzing customer data
# 2. research >> study patterns in data (say, researching on dna, a star, a car engine, or anything else)

# %% [markdown]
# ### **uses of statistics**
# could be literally a lot of things. in fact almost anything. we use it in biology, physic, chemistry, sports, campains, content creation, energy production, information exchange, etc. all to come to a conclusion.
