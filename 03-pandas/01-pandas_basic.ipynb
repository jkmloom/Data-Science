# %%
# pandas is a fast, powerful, flexible and easy yo use open source data analysis and manipulartion tool built on top of the pyhton programming language
# pandas was developed in 2008 by Mckinney
# very useful with structured data (eg. tabular data)

# %%
import pandas as pd
dataframe_path = "../00.1-data/services.csv"

# %%
# reading a cvs (comma separated values) file using pandas
df = pd.read_csv(dataframe_path)
# by default pandas understands the 1st row are column names
df
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# in case if the data has no header (column name)
pd.read_csv(dataframe_path, header = None)
# internal integer indexes are provided by pandas for both rows and columns
# Out:
#     0            1           2                         3   \
# 0   id  location_id  program_id         accepted_payments
# 1    1            1         NaN                       NaN
# 2    2            2         NaN                       NaN
# 3    3            3         NaN                       NaN
# 4    4            4         NaN                       NaN
# 5    5            5         NaN                       NaN
# 6    6            6         NaN                       NaN
# 7    7            7         NaN                       NaN
# 8    8            8         NaN                       NaN
# 9    9            9         NaN                       NaN
# 10  10           10         NaN                       NaN
# 11  11           11         NaN                       NaN
# 12  12           12         NaN                       NaN
# 13  13           13         NaN                       NaN
# 14  14           14         NaN                       NaN
# ...

# %%
# suppose we don't want the first rows
pd.read_csv(dataframe_path, skiprows=2)
# Out:
#      2  2.1  Unnamed: 2                Unnamed: 3             Unnamed: 4  \
# 0    3    3         NaN                       NaN                    NaN
# 1    4    4         NaN                       NaN                    NaN
# 2    5    5         NaN                       NaN                    NaN
# 3    6    6         NaN                       NaN                    NaN
# 4    7    7         NaN                       NaN                    NaN
# 5    8    8         NaN                       NaN                    NaN
# 6    9    9         NaN                       NaN                    NaN
# 7   10   10         NaN                       NaN                    NaN
# 8   11   11         NaN                       NaN                    NaN
# 9   12   12         NaN                       NaN                    NaN
# 10  13   13         NaN                       NaN                    NaN
# 11  14   14         NaN                       NaN                    NaN
# ...

# %%
# lets say we want to see only 3 columns
pd.read_csv(dataframe_path, usecols=["program_id", "application_process"])
# Out:
#     program_id                                application_process
# 0          NaN                         Walk in or apply by phone.
# 1          NaN                 Apply by phone for an appointment.
# 2          NaN        Phone for information (403-4300 Ext. 4322).
# 3          NaN                                    Apply by phone.
# 4          NaN                             Phone for information.
# 5          NaN  Walk in or apply by phone for membership appli...
# 6          NaN  Apply by phone or be referred by a doctor, soc...
# 7          NaN                                    Apply by phone.
# 8          NaN  Walk in. Proof of residency in California requ...
# 9          NaN  Walk in. Proof of California residency to rece...
# 10         NaN  Walk in. Proof of California residency require...
# 11         NaN  Walk in or apply by phone, email or webpage re...
# 12         NaN  Walk in. Proof of California residency require...
# ...

# %%
print(pd.read_csv(dataframe_path))
# Out:
#     id  location_id  program_id         accepted_payments  \
# 0    1            1         NaN                       NaN
# 1    2            2         NaN                       NaN
# 2    3            3         NaN                       NaN
# 3    4            4         NaN                       NaN
# 4    5            5         NaN                       NaN
# 5    6            6         NaN                       NaN
# 6    7            7         NaN                       NaN
# 7    8            8         NaN                       NaN
# 8    9            9         NaN                       NaN
# 9   10           10         NaN                       NaN
# 10  11           11         NaN                       NaN
# 11  12           12         NaN                       NaN
# 12  13           13         NaN                       NaN
# 13  14           14         NaN                       NaN
# 14  15           15         NaN                       NaN
# ...

# %%
# data structures in pandas >> here data are stored in the form of series and dataframe
# series >> 1 dimentional in nature
# dataframe >> 2 dimentional in nature

# %%
# what type is the variable 'df' we were using till now
type(df)
# Out:
# pandas.DataFrame

# %%
# access a particular column
df.application_process
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
# another way to do the same
df["application_process"] # prefered method
# Out:
# 0                            Walk in or apply by phone.
# 1                    Apply by phone for an appointment.
# 2           Phone for information (403-4300 Ext. 4322).
# 3                                       Apply by phone.
# 4                                Phone for information.
# 5     Walk in or apply by phone for membership appli...
# 6     Apply by phone or be referred by a doctor, soc...
# 7                                       Apply by phone.
# 8     Walk in. Proof of residency in California requ...
# 9     Walk in. Proof of California residency to rece...
# 10    Walk in. Proof of California residency require...
# 11    Walk in or apply by phone, email or webpage re...
# 12    Walk in. Proof of California residency require...
# 13    Call for appointment. Referral from human serv...
# 14            Walk in or through other agency referral.
# 15    Walk in. Written application, identification r...
# 16                                Call for information.
# ...

# %%
# a column of a dataframe is a series
type(df["application_process"])
# Out:
# pandas.Series

# %%
lvar = [1, 2, 3, 4]
s = pd.Series(lvar)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
# we can use slicing techniqe in series just like in a list
print(s[1:])
print(s[2:4])
# Out:
# 1    2
# 2    3
# 3    4
# dtype: int64
# 2    3
# 3    4
# dtype: int64

# %%
# by default the indexes are integer
# but we can have custom indexes
d = pd.Series([100, 200, 300], index = ["jkmloom", "jkmcode", "jkmjatin"])
print(d)
# Out:
# jkmloom     100
# jkmcode     200
# jkmjatin    300
# dtype: int64

# %%
type(d)
# Out:
# pandas.Series

# %%
# slicing on custom index
d["jkmcode"]
# Out:
# np.int64(200)

# %%
# to see all the index of the series
d.index
# Out:
# Index(['jkmloom', 'jkmcode', 'jkmjatin'], dtype='str')

# %%
# to reset index
d.reset_index(drop=True)
# Out:
# 0    100
# 1    200
# 2    300
# dtype: int64

# %%
# convert a series into dataframe
pd.DataFrame(d)
# Out:
#             0
# jkmloom   100
# jkmcode   200
# jkmjatin  300

# %%
# multiple series combines to form a dataframe 
df_2 = pd.DataFrame(d)
print(f"Dataframe:\n{df_2}\n{"***"*14}\nVariable type: {type(df_2)}")
# Out:
# Dataframe:
#             0
# jkmloom   100
# jkmcode   200
# jkmjatin  300
# ******************************************
# Variable type: <class 'pandas.DataFrame'>

# %%
# first 5 rows of the datafram
print(df.head())
# Out:
#    id  location_id  program_id accepted_payments alternate_name  \
# 0   1            1         NaN               NaN            NaN
# 1   2            2         NaN               NaN            NaN
# 2   3            3         NaN               NaN            NaN
# 3   4            4         NaN               NaN            NaN
# 4   5            5         NaN               NaN            NaN
#
#                            application_process  \
# 0                   Walk in or apply by phone.
# 1           Apply by phone for an appointment.
# 2  Phone for information (403-4300 Ext. 4322).
# 3                              Apply by phone.
# 4                       Phone for information.
#
#                                             audience  \
# 0  Older adults age 55 or over, ethnic minorities...
# 1       Residents of San Mateo County age 55 or over
# 2  Older adults age 55 or over who can benefit fr...
# 3  Parents, children, families with problems of c...
# ...

# %%
# last five rows of the dataframe
print(df.tail())
# Out:
#     id  location_id  program_id         accepted_payments  \
# 18  19           19         NaN                       NaN
# 19  20           20         NaN                       NaN
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                             application_process  \
# 18                    NaN  Call for screening appointment (650-347-3648).
# 19                    NaN                                        Walk in.
# 20                    NaN                 By phone during business hours.
# 21  Fotos para pasaportes               Walk in or apply by phone or mail
# 22                    NaN               Walk in or apply by phone or mail
#
#                                              audience  \
# 18                                                NaN
# 19                                                NaN
# ...

# %%
# defined number of rows from the end
print(df.tail(3)) # defined number here: 3
# Out:
#     id  location_id  program_id         accepted_payments  \
# 20  21           21         NaN                       NaN
# 21  22           22         NaN  Cash, Check, Credit Card
# 22  23           22         NaN                       NaN
#
#            alternate_name                application_process  \
# 20                    NaN    By phone during business hours.
# 21  Fotos para pasaportes  Walk in or apply by phone or mail
# 22                    NaN  Walk in or apply by phone or mail
#
#                                              audience  \
# 20                                                NaN
# 21  Profit and nonprofit businesses, the public, m...
# 22  Second service and nonprofit businesses, the p...
#
#                                           description eligibility  \
# 20                                just a test service         NaN
# 21  [NOTE THIS IS NOT A REAL SERVICE--THIS IS FOR ...         NaN
# ...

# %%
# shape (number of columns and rows) of the dataframe
print(f"Dataframe shape: {df.shape}")
# Out:
# Dataframe shape: (23, 22)

# %%
# columns of a dataframe
print(df.columns)
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='str')

# %%
# convert the columns into a list
list(df.columns)
# Out:
# ['id',
#  'location_id',
#  'program_id',
#  'accepted_payments',
#  'alternate_name',
#  'application_process',
#  'audience',
#  'description',
#  'eligibility',
#  'email',
#  'fees',
#  'funding_sources',
#  'interpretation_services',
#  'keywords',
#  'languages',
#  'name',
#  'required_documents',
#  'service_areas',
#  'status',
#  'wait_time',
#  'website',
#  'taxonomy_ids']

# %%
# see a randow row from the dataframe
df.sample() # default: returns 1 value
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 17  18           18         NaN               NaN            NaN
#
#                                   application_process audience  \
# 17  Call for screening appointment. Medical visits...      NaN
#
#                                           description  \
# 17  By appointment only, Project Smile provides a ...
#
#                                         eligibility email  ...  \
# 17  Low-income person without access to health care   NaN  ...
#
#    interpretation_services                                           keywords  \
# 17                     NaN  HEALTH SERVICES, Outpatient Care, Community Cl...
#
#    languages           name required_documents   service_areas  status  \
# 17       NaN  Project Smile                NaN  East Palo Alto  active
#
#    wait_time website taxonomy_ids
# 17   Varies.     NaN          NaN
#
# [1 rows x 22 columns]

# %%
# defined number of random rows from a dataframe
print(df.sample(3))
# Out:
#     id  location_id  program_id accepted_payments alternate_name  \
# 2    3            3         NaN               NaN            NaN
# 15  16           16         NaN               NaN            NaN
# 8    9            9         NaN               NaN            NaN
#
#                                   application_process  \
# 2         Phone for information (403-4300 Ext. 4322).
# 15  Walk in. Written application, identification r...
# 8   Walk in. Proof of residency in California requ...
#
#                                              audience  \
# 2   Older adults age 55 or over who can benefit fr...
# 15                                                NaN
# 8      Ethnic minorities, especially Spanish speaking
#
#                                           description  \
# 2   Offers supportive counseling services to San M...
# 15  Provides emergency assistance including food a...
# 8   Provides general reading material, including b...
#
# ...

# %%
# check infromation about the dataframe in pandas
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      str
#  4   alternate_name           1 non-null      str
#  5   application_process      23 non-null     str
#  6   audience                 14 non-null     str
#  7   description              23 non-null     str
#  8   eligibility              17 non-null     str
#  9   email                    1 non-null      str
#  10  fees                     21 non-null     str
#  11  funding_sources          21 non-null     str
#  12  interpretation_services  1 non-null      str
#  13  keywords                 21 non-null     str
#  14  languages                1 non-null      str
# ...

# %%
# check data types in a dataframe
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments              str
# alternate_name                 str
# application_process            str
# audience                       str
# description                    str
# eligibility                    str
# email                          str
# fees                           str
# funding_sources                str
# interpretation_services        str
# keywords                       str
# languages                      str
# name                           str
# required_documents             str
# service_areas                  str
# status                         str
# wait_time                      str
# website                        str
# taxonomy_ids                   str
# dtype: object

# %%
# revise: dataframe is a collection of series
print(type(df['id']))
# Out:
# <class 'pandas.Series'>

# %%
type(df["application_process"])
# Out:
# pandas.Series

# %%
list(df["application_process"])
# Out:
# ['Walk in or apply by phone.',
#  'Apply by phone for an appointment.',
#  'Phone for information (403-4300 Ext. 4322).',
#  'Apply by phone.',
#  'Phone for information.',
#  'Walk in or apply by phone for membership application.',
#  'Apply by phone or be referred by a doctor, social worker or other professional. All prospective participants are interviewed individually before starting the program. A recent physical examination is required, including a TB test.',
#  'Apply by phone.',
#  'Walk in. Proof of residency in California required to receive a library card.',
#  'Walk in. Proof of California residency to receive a library card.',
#  'Walk in. Proof of California residency required to receive a library card.',
#  'Walk in or apply by phone, email or webpage registration.',
#  'Walk in. Proof of California residency required to receive a library card.',
#  'Call for appointment. Referral from human service professional preferred for emergency assistance.',
# ...

# %%
# convert series to dataframe
s = pd.Series([2, 3, 4], index=[100, "jkmloom", 500])
print(f"Data:\n{s}\nType: {type(s)}")
# Out:
# Data:
# 100        2
# jkmloom    3
# 500        4
# dtype: int64
# Type: <class 'pandas.Series'>

# %%
# conversion
d = pd.DataFrame(s)
print(f"Dataframe:\n{d}\nType: {type(d)}")
# Out:
# Dataframe:
#          0
# 100      2
# jkmloom  3
# 500      4
# Type: <class 'pandas.DataFrame'>

# %%
d
# Out:
#          0
# 100      2
# jkmloom  3
# 500      4

# %%
# making a new column in a dataframe
d["new column"] = "jkmloom"
d
# Out:
#          0 new column
# 100      2    jkmloom
# jkmloom  3    jkmloom
# 500      4    jkmloom

# %%
d["custom column"] = ["jkmloom", "jkmcode", "jkmjatin"]
d
# Out:
#          0 new column custom column
# 100      2    jkmloom       jkmloom
# jkmloom  3    jkmloom       jkmcode
# 500      4    jkmloom      jkmjatin

# %%
# new column elements = number of rows/data entry required
d["new_column2"] = [1, 2, 3]
d
# Out:
#          0 new column custom column  new_column2
# 100      2    jkmloom       jkmloom            1
# jkmloom  3    jkmloom       jkmcode            2
# 500      4    jkmloom      jkmjatin            3

# %%
# column names
d.columns
# Out:
# Index([0, 'new column', 'custom column', 'new_column2'], dtype='object')

# %%
# update column names
d.columns = ["col1", "col2", "col3", "col4"]
d
# Out:
#          col1     col2      col3  col4
# 100         2  jkmloom   jkmloom     1
# jkmloom     3  jkmloom   jkmcode     2
# 500         4  jkmloom  jkmjatin     3

# %%
# reset index
print(d.reset_index()) # without drop=True
print("***"*14)
print(d.reset_index(drop=True)) # with drop=True
# Out:
#      index  col1     col2      col3  col4
# 0      100     2  jkmloom   jkmloom     1
# 1  jkmloom     3  jkmloom   jkmcode     2
# 2      500     4  jkmloom  jkmjatin     3
# ******************************************
#    col1     col2      col3  col4
# 0     2  jkmloom   jkmloom     1
# 1     3  jkmloom   jkmcode     2
# 2     4  jkmloom  jkmjatin     3

# %%
# accessing one column
df["status"]
# Out:
# 0       active
# 1       active
# 2       active
# 3       active
# 4       active
# 5       active
# 6       active
# 7       active
# 8       active
# 9       active
# 10      active
# 11      active
# 12      active
# 13      active
# 14      active
# 15      active
# 16      active
# 17      active
# 18      active
# 19     defunct
# 20    inactive
# 21      active
# 22      active
# Name: status, dtype: str

# %%
# accessing multiple columns together
# df["status", "languages"] >> this method won't work cause series are 1 dimentional in nature
df_subset = df[["name", "status", "languages"]]
# above method will work cause it's converted to a dataframe using [[douple_paired_square_brackest]]
# aka >> subset of a dataframe
print(df_subset)
# Out:
#                                     name    status languages
# 0        Fair Oaks Adult Activity Center    active       NaN
# 1       Second Career Employment Program    active       NaN
# 2                 Senior Peer Counseling    active       NaN
# 3               Family Visitation Center    active       NaN
# 4      Economic Self-Sufficiency Program    active       NaN
# 5   Little House Recreational Activities    active       NaN
# 6       Rosener House Adult Day Services    active       NaN
# 7         Meals on Wheels - South County    active       NaN
# 8                       Fair Oaks Branch    active       NaN
# 9                           Main Library    active       NaN
# 10                       Schaberg Branch    active       NaN
# 11                          Project Read    active       NaN
# 12                 Redwood Shores Branch    active       NaN
# 13                    Redwood City Corps    active       NaN
# ...

# %%
type(df_subset)
# Out:
# pandas.DataFrame

# %%
# reading excel files using pandas
excel_file_path= "../00.1-data/LUSID Excel - Setting up your market data.xlsx"
pd.read_excel(excel_file_path)
# Out:
#     Unnamed: 0  Unnamed: 1  Unnamed: 2  \
# 0          NaN         NaN         NaN
# 1          NaN         NaN         NaN
# 2          NaN         NaN         NaN
# 3          NaN         NaN         NaN
# 4          NaN         NaN         NaN
# 5          NaN         NaN         NaN
# 6          NaN         NaN         NaN
# 7          NaN         NaN         NaN
# 8          NaN         NaN         NaN
# 9          NaN         NaN         NaN
# 10         NaN         NaN         NaN
# 11         NaN         NaN         NaN
# 12         NaN         NaN         NaN
# 13         NaN         NaN         NaN
# 14         NaN         NaN         NaN
# 15         NaN         NaN         NaN
# 16         NaN         NaN         NaN
# 17         NaN         NaN         NaN
# 18         NaN         NaN         NaN
# 19         NaN         NaN         NaN
# 20         NaN         NaN         NaN
# 21         NaN         NaN         NaN
# 22         NaN         NaN         NaN
# ...

# %%
# opeerations are mostly gonna be same
df1 = pd.read_excel(excel_file_path)

# %%
df.shape
# Out:
# (23, 22)

# %%
df.columns
# Out:
# Index(['id', 'location_id', 'program_id', 'accepted_payments',
#        'alternate_name', 'application_process', 'audience', 'description',
#        'eligibility', 'email', 'fees', 'funding_sources',
#        'interpretation_services', 'keywords', 'languages', 'name',
#        'required_documents', 'service_areas', 'status', 'wait_time', 'website',
#        'taxonomy_ids'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 22 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       23 non-null     int64
#  1   location_id              23 non-null     int64
#  2   program_id               0 non-null      float64
#  3   accepted_payments        1 non-null      str
#  4   alternate_name           1 non-null      str
#  5   application_process      23 non-null     str
#  6   audience                 14 non-null     str
#  7   description              23 non-null     str
#  8   eligibility              17 non-null     str
#  9   email                    1 non-null      str
#  10  fees                     21 non-null     str
#  11  funding_sources          21 non-null     str
#  12  interpretation_services  1 non-null      str
#  13  keywords                 21 non-null     str
#  14  languages                1 non-null      str
# ...

# %%
df.dtypes
# Out:
# id                           int64
# location_id                  int64
# program_id                 float64
# accepted_payments              str
# alternate_name                 str
# application_process            str
# audience                       str
# description                    str
# eligibility                    str
# email                          str
# fees                           str
# funding_sources                str
# interpretation_services        str
# keywords                       str
# languages                      str
# name                           str
# required_documents             str
# service_areas                  str
# status                         str
# wait_time                      str
# website                        str
# taxonomy_ids                   str
# dtype: object

# %%
# reading another csv file
taxonomy = "../00.1-data/taxonomy.csv"
another_df = pd.read_csv(taxonomy)
print(another_df)
# Out:
#     taxonomy_id                          name parent_id           parent_name
# 0           101                     Emergency       NaN                   NaN
# 1        101-01             Disaster Response       101             Emergency
# 2        101-02                Emergency Cash       101             Emergency
# 3     101-02-01             Help Pay for Food    101-02        Emergency Cash
# 4     101-02-02       Help Pay for Healthcare    101-02        Emergency Cash
# ..          ...                           ...       ...                   ...
# 285   111-01-07              Workplace Rights    111-01  Advocacy & Legal Aid
# 286      111-02                     Mediation       111                 Legal
# 287      111-03                        Notary       111                 Legal
# 288      111-04                Representation       111                 Legal
# 289      111-05  Translation & Interpretation       111                 Legal
#
# [290 rows x 4 columns]

# %%
# reading csv/data from a file online
df3 = pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df3.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 83.7 KB

# %%
df3.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df3.shape
# Out:
# (891, 12)

# %%
df3.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
print(df3.Sex) # or
print("***"*15)
print(df3["Sex"]) # prefered method
# Out:
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: str
# *********************************************
# 0        male
# 1      female
# 2      female
# 3      female
# 4        male
#         ...
# 886      male
# 887    female
# 888    female
# 889      male
# 890      male
# Name: Sex, Length: 891, dtype: str

# %%
# subset of the dataframe
df3[["PassengerId", "Name", "Sex"]]
# Out:
#      PassengerId                                               Name     Sex
# 0              1                            Braund, Mr. Owen Harris    male
# 1              2  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2              3                             Heikkinen, Miss. Laina  female
# 3              4       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4              5                           Allen, Mr. William Henry    male
# ..           ...                                                ...     ...
# 886          887                              Montvila, Rev. Juozas    male
# 887          888                       Graham, Miss. Margaret Edith  female
# 888          889           Johnston, Miss. Catherine Helen "Carrie"  female
# 889          890                              Behr, Mr. Karl Howell    male
# 890          891                                Dooley, Mr. Patrick    male
#
# [891 rows x 3 columns]

# %%
# reading html file onlint using pandas

# %%
df4 = pd.read_html("http://www.contextures.com/xlSampleData01.html")
print(df4)
# Out:
# [                                                   0  \
# 0  Home > Data > Sample > Sample Data Excel Sampl...
# 1                                                NaN
#
#                                                    1
# 0                                                NaN
# 1  Get this Microsoft Excel sample data for pract...  ,     0                                                  1
# 0 NaN  Get this Microsoft Excel sample data for pract...,              0        1         2        3      4         5        6
# 0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
# 1     1/6/2024     East     Jones   Pencil     95      1.99   189.05
# 2    1/23/2024  Central    Kivell   Binder     50     19.99   999.50
# 3     2/9/2024  Central   Jardine   Pencil     36      4.99   179.64
# 4    2/26/2024  Central      Gill      Pen     27     19.99   539.73
# 5    3/15/2024     West   Sorvino   Pencil     56      2.99   167.44
# ...

# %%
df4
# Out:
# [                                                   0  \
#  0  Home > Data > Sample > Sample Data Excel Sampl...
#  1                                                NaN
#
#                                                     1
#  0                                                NaN
#  1  Get this Microsoft Excel sample data for pract...  ,
#      0                                                  1
#  0 NaN  Get this Microsoft Excel sample data for pract...,
#               0        1         2        3      4         5        6
#  0    OrderDate   Region       Rep     Item  Units  UnitCost    Total
#  1     1/6/2024     East     Jones   Pencil     95      1.99   189.05
#  2    1/23/2024  Central    Kivell   Binder     50     19.99   999.50
#  3     2/9/2024  Central   Jardine   Pencil     36      4.99   179.64
#  4    2/26/2024  Central      Gill      Pen     27     19.99   539.73
#  5    3/15/2024     West   Sorvino   Pencil     56      2.99   167.44
# ...

# %%
type(df4)
# Out:
# list

# %% [markdown]
# i could not find an url to a html file (that could be accessed simply in one line of code) so i used an url to a list file instead.
# hence, some functions/operations could not be performed that you may expect from a normal html file.

# %%
df4.to_csv("../00.1-data/html_data_reading.csv", index=False)
# index=False >> we dont want the index to be entered in the csv file cause csv creates index on it's own
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 df4.to_csv("../00.1-data/html_data_reading.csv", index=False)
#       2 # index=False >> we dont want the index to be entered in the csv file cause csv creates index on it's own
#
# AttributeError: 'list' object has no attribute 'to_csv'

# %%
# reading online json file using pandas
url = "https://api.github.com/repos/pandas-dev/pandas/issues"
pd.read_json(url)
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# ...

# %%
import requests
data = requests.get(url)

# %%
data
# Out:
# <Response [200]>

# %%
data.json()
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/64412',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/64412/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/64412/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/64412/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/64412',
#   'id': 4029361259,
#   'node_id': 'PR_kwDOAA0YD87IQn8v',
#   'number': 64412,
#   'title': 'DOC: fix dtype dict examples in read_csv/read_table',
#   'user': {'login': 'mitre88',
#    'id': 30060514,
#    'node_id': 'MDQ6VXNlcjMwMDYwNTE0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30060514?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/mitre88',
#    'html_url': 'https://github.com/mitre88',
# ...
