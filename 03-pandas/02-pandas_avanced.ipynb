# %%
import pandas as pd

# %%
# reading titanic_dataset.csv
df = pd.read_csv("../00.1-data/titanic.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# view column titles from the dataset
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='str')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# datatypes available in the dataset
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name               str
# Sex                str
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket             str
# Fare           float64
# Cabin              str
# Embarked           str
# dtype: object

# %%
# age column has string value, but we need it to be int

# 'coerce' turns non-numbers into NaN (Not a Number)
df['Age'] = pd.to_numeric(df['Age'], errors='coerce')
# Since NaN is a float, you'll need to fill them before converting to int
df['Age'] = df['Age'].fillna(0).astype(int)

# %%
# information on dataset
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
# dtypes: float64(1), int64(6), str(5)
# memory usage: 83.7 KB

# %%
# statistical info about the numerical columns
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.783389    0.523008
# std     257.353842    0.486592    0.836071   17.597344    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 5 point summary >> min, 25%, 50%, 75%, max

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# subset of the dataframe
df[['PassengerId', 'Survived', "Pclass"]]
# Out:
#      PassengerId  Survived  Pclass
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
# [891 rows x 3 columns]

# %%
# check for columns with int values
df.dtypes == "int" # object is a string datatype
# Out:
# PassengerId     True
# Survived        True
# Pclass          True
# Name           False
# Sex            False
# Age             True
# SibSp           True
# Parch           True
# Ticket         False
# Fare           False
# Cabin          False
# Embarked       False
# dtype: bool

# %%
# get only columns (or series values) with int values
df.dtypes[df.dtypes == "int"]
# Out:
# PassengerId    int64
# Survived       int64
# Pclass         int64
# Age            int64
# SibSp          int64
# Parch          int64
# dtype: object

# %%
# to get the index
df.dtypes[df.dtypes == "int"].index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch'], dtype='str')

# %%
# the string data
df[df.dtypes[df.dtypes == "str"].index]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# for numerical data
df[df.dtypes[df.dtypes != "str"].index]
# Out:
#      PassengerId  Survived  Pclass  Age  SibSp  Parch     Fare
# 0              1         0       3   22      1      0   7.2500
# 1              2         1       1   38      1      0  71.2833
# 2              3         1       3   26      0      0   7.9250
# 3              4         1       1   35      1      0  53.1000
# 4              5         0       3   35      0      0   8.0500
# ..           ...       ...     ...  ...    ...    ...      ...
# 886          887         0       2   27      0      0  13.0000
# 887          888         1       1   19      0      0  30.0000
# 888          889         0       3    0      1      2  23.4500
# 889          890         1       1   26      0      0  30.0000
# 890          891         0       3   32      0      0   7.7500
#
# [891 rows x 7 columns]

# %%
df[df.dtypes[df.dtypes != "str"].index].describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.783389    0.523008
# std     257.353842    0.486592    0.836071   17.597344    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   23.783389    0.523008
# std     257.353842    0.486592    0.836071   17.597344    1.102743
# min       1.000000    0.000000    1.000000    0.000000    0.000000
# 25%     223.500000    0.000000    2.000000    6.000000    0.000000
# 50%     446.000000    0.000000    3.000000   24.000000    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
df.describe(include = "object")
# Out:
# /tmp/ipykernel_4129/3591357663.py:1: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.describe(include = "object")
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
df.describe(include = "all")
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
# ...

# %%
# returns the statistical information considring categorical column
df.astype("object").describe()
# Out:
#         PassengerId  Survived  Pclass                     Name   Sex  Age  \
# count           891       891     891                      891   891  891
# unique          891         2       3                      891     2   71
# top               1         0       3  Braund, Mr. Owen Harris  male    0
# freq              1       549     491                        1   577  184
#
#         SibSp  Parch  Ticket    Fare Cabin Embarked
# count     891    891     891  891.00   204      889
# unique      7      7     681  248.00   147        3
# top         0      0  347082    8.05    G6        S
# freq      608    678       7   43.00     4      644

# %%
# revise dataframe
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
# slicing the dataset
df[:100]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# ..          ...       ...     ...
# 95           96         0       3
# 96           97         0       1
# 97           98         1       1
# 98           99         1       2
# 99          100         0       2
#
#                                                  Name     Sex  Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   22      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                              Heikkinen, Miss. Laina  female   26      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                            Allen, Mr. William Henry    male   35      0
# ..                                                ...     ...  ...    ...
# ...

# %%
# for every 5th element
df[:100:5]
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 5             6         0       3
# 10           11         1       3
# 15           16         1       2
# 20           21         0       2
# 25           26         1       3
# 30           31         0       1
# 35           36         0       1
# 40           41         0       3
# 45           46         0       3
# 50           51         0       3
# 55           56         1       1
# 60           61         0       3
# 65           66         1       3
# 70           71         0       2
# 75           76         0       3
# 80           81         0       3
# 85           86         1       3
# 90           91         0       3
# 95           96         0       3
#
#                                                  Name     Sex  Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male   22      1
# 5                                    Moran, Mr. James    male    0      0
# ...

# %%
# create a new column
df["new_col"] = "jkmloom"

# %%
# view updated dataset
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
# create a ne column from a existing column
# example: here a "family" column
df["Family"] = df["SibSp"] + df["Parch"]

# %%
# view dataset
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    str
#  4   Sex          891 non-null    str
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    str
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    str
#  11  Embarked     889 non-null    str
#  12  new_col      891 non-null    str
#  13  Family       891 non-null    int64
# dtypes: float64(1), int64(7), str(6)
# memory usage: 97.6 KB

# %%
# different categories of a column
# here: Pclass
pd.Categorical(df["Pclass"])
# Out:
# [3, 1, 3, 1, 3, ..., 2, 1, 3, 1, 3]
# Length: 891
# Categories (3, int64): [1, 2, 3]

# %%
pd.Categorical(df["Cabin"])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, str): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
# looking for the unique values
df["Cabin"].unique()
# Out:
# <StringArray>
# [          nan,         'C85',        'C123',         'E46',          'G6',
#         'C103',         'D56',          'A6', 'C23 C25 C27',         'B78',
#  ...
#         'B102',         'B69',         'E49',         'C47',         'D28',
#          'E17',         'A24',         'C50',         'B42',        'C148']
# Length: 148, dtype: str

# %%
df["Pclass"].unique()
# Out:
# array([3, 1, 2])

# %%
df["Sex"].unique()
# Out:
# <StringArray>
# ['male', 'female']
# Length: 2, dtype: str

# %%
# counting the unique values
df["Cabin"].nunique()
# Out:
# 147

# %%
# getting the magnitue (or count) of the unique values
df["Sex"].value_counts()
# Out:
# Sex
# male      577
# female    314
# Name: count, dtype: int64

# %%
# when you need the magnitude values in percentage
df["Sex"].value_counts(normalize = True)
# Out:
# Sex
# male      0.647587
# female    0.352413
# Name: proportion, dtype: float64

# %% [markdown]
# while reading the values in percentage, shift the decimal 2 places to the right

# %%
# or
df["Sex"].value_counts(normalize = True) * 100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
# problem solving

# %%
# start developing a thought process
'''1. how many passengers are less than 5 years old ?'''
df[df["Age"] < 5]
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 5              6         0       3                          Moran, Mr. James
# 7              8         0       3            Palsson, Master. Gosta Leonard
# 10            11         1       3           Sandstrom, Miss. Marguerite Rut
# 16            17         0       3                      Rice, Master. Eugene
# 17            18         1       2              Williams, Mr. Charles Eugene
# ..           ...       ...     ...                                       ...
# 863          864         0       3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869         0       3               van Melkebeke, Mr. Philemon
# 869          870         1       3           Johnson, Master. Harold Theodor
# 878          879         0       3                        Laleff, Mr. Kristo
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
#
# ...

# %%
df[df["Age"] < 5].shape
# Out:
# (217, 12)

# %%
# another method
len(df[df["Age"] < 5])

# so there are 217 people below the age of 5 on the titanic ship
# Out:
# 217

# %%
df[df["Age"] == 0].shape
# Out:
# (184, 12)

# %%
print(f"since there are {len(df[df["Age"] == 0])} people with age 0, this is likely an error (missing data) but we'll deal with this later")
# Out:
# since there are 184 people with age 0, this is likely an error (missing data) but we'll deal with this later

# %%
'''2. name of the children with age < 5'''
df[df["Age"] < 5]["Name"]
# Out:
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
# 10              Sandstrom, Miss. Marguerite Rut
# 16                         Rice, Master. Eugene
# 17                 Williams, Mr. Charles Eugene
#                          ...
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 869             Johnson, Master. Harold Theodor
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 217, dtype: str

# %%
# or another way could have been
df[df["Age"] < 5].Name
# Out:
# 5                              Moran, Mr. James
# 7                Palsson, Master. Gosta Leonard
# 10              Sandstrom, Miss. Marguerite Rut
# 16                         Rice, Master. Eugene
# 17                 Williams, Mr. Charles Eugene
#                          ...
# 863           Sage, Miss. Dorothy Edith "Dolly"
# 868                 van Melkebeke, Mr. Philemon
# 869             Johnson, Master. Harold Theodor
# 878                          Laleff, Mr. Kristo
# 888    Johnston, Miss. Catherine Helen "Carrie"
# Name: Name, Length: 217, dtype: str

# %%
len(list(df[df["Age"] < 5].Name))
# we can see that the number of names = number of people with age < 5
# Out:
# 217

# %%
'''3. how many people are less than 18 years old ?'''
len(df[df["Age"]  < 18])
# Out:
# 290

# %%
'''4. how many people are less than or eual to 18 years of age ?'''
len(df[df["Age"] <= 18])
# Out:
# 316

# %%
'''5. how many passengers have paid less than the average fair?'''
# view over the dataset for once
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex  Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male   22      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female   38      1
# 2                               Heikkinen, Miss. Laina  female   26      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female   35      1
# 4                             Allen, Mr. William Henry    male   35      0
# ..                                                 ...     ...  ...    ...
# ...

# %%
avg_fare = df["Fare"].mean()
print("Average fare:",avg_fare)
# Out:
# Average fare: 32.204207968574636

# %%
len(df[df["Fare"] < avg_fare])
# so 680 paid less than the average fare on the titanic ship
# Out:
# 680

# %%
'''6. how many passengers have paid no (0) fare ?'''
len(df[df["Fare"] == 0])
# Out:
# 15

# %%
'''7. how many passengers were male ?'''
len(df[df["Sex"] == "male"])
# Out:
# 577

# %%
'''8. how many passengers were female ?'''
len(df[df["Sex"] == "female"])
# Out:
# 314

# %%
'''8. what percentage of male and female were on the ship ?'''
df["Sex"].value_counts(normalize = True) * 100
# Out:
# Sex
# male      64.758698
# female    35.241302
# Name: proportion, dtype: float64

# %%
'''9. how many passengers were in class 1 ?'''
len(df[df["Pclass"] == 1])
# Out:
# 216

# %%
'''10. how many passenegers survived ?'''
len(df[df["Survived"] == 1])
# Out:
# 342

# %%
'''11. how many people survived with fare above then average ?'''
len(df[(df["Survived"]) & (df["Fare"] > df["Fare"].mean())])
# Out:
# 126

# %%
'''12. how many females paid more then average fare ?'''
df["Sex"] == "female"
# Out:
# 0      False
# 1       True
# 2       True
# 3       True
# 4      False
#        ...
# 886    False
# 887     True
# 888     True
# 889    False
# 890    False
# Name: Sex, Length: 891, dtype: bool

# %%
len(df[(df["Sex"] == "female") & (df["Fare"] > df["Fare"].mean())])
# so 104 females paid above than average fare
# Out:
# 104

# %%
'''13. how name male paid above average fair ?'''
len(df[(df["Sex"] == "male") & (df["Fare"] > df["Fare"].mean())])
# Out:
# 107

# %%
# we can even use numpy for finding the average fare
import numpy as np

np.mean(df["Fare"])
# Out:
# np.float64(32.204207968574636)

# %%
# another way
df.Fare.mean()
# Out:
# np.float64(32.204207968574636)

# %%
'''14. what was the maximum amount of fare ?'''
max(df["Fare"])
# Out:
# 512.3292

# %%
'''15. what was the minimum amout of fair ?'''
min(df["Fare"])
# Out:
# 0.0

# %%
'''16. who were the people paying maximum fare ?'''
df[df["Fare"] == max(df["Fare"])].Name
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: str

# %%
'''17. average age of the people paying more than the average fare ?'''
df[df["Fare"] > df["Fare"].mean()].Age.mean()
# Out:
# np.float64(28.635071090047393)
